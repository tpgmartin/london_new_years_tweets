# %%
import pandas as pd

# %%
# CSV files
# pop_density+n_tweets_by_wards_hours_2015_01_05_18.csv
# tweets_by_hours_London_wards_2014_12_01_21.csv
# tweets_by_hours_London_wards_2014_12_22_2015_01_11.csv

# %%
tweets_all = pd.read_csv("./data/tweets_all.csv", encoding="latin1")

# %%
tweets_all.head()
# Out:
#                    id  Name         X          Y  LONGITUDE   LATITUDE  \
# 0  550226818624942080   NaN -0.262150  51.391407  -0.262150  51.391407
# 1  550226823314178048   NaN -0.149466  51.492560  -0.149466  51.492561
# 2  550226827944660992   NaN -0.014891  51.354042  -0.014891  51.354042
# 3  550226837537058816   NaN  0.006698  51.532020   0.006698  51.532021
# 4  550227214227505152   NaN  0.214417  51.582535   0.214417  51.582535
#
#            MESSAGEDATE     USERID   USERSCREENNAME  \
# 0  31/12/2014 09:47:50  113918054     12Elbestreet
# 1  31/12/2014 09:47:52  465989904  alice_foster_95
# 2  31/12/2014 09:47:53   55872342      MissGee_Pee
# 3  31/12/2014 09:47:55  147266450    vinita_ramtri
# 4  31/12/2014 09:49:25  518928608    CallumGordon7
#
#                                          MESSAGETEXT  \
# 0  @julieo25 Not yet got tics for Liverpool waiti...
# 1     So. Many. Accents #alicesadventureswithmegabus
# 2  If it doesn't make you happy by December 31st....
# ...

# %%
tweets_all.shape
# Out:
# (119850, 13)

# %%
london_tweets = tweets_all[tweets_all.LOCATION.str.contains("London")]

# %%
london_tweets.shape
# Out:
# (106550, 13)

# %%
london_tweets.to_csv("./data/london_tweets.csv", index=False)

# %%
london_tweets.head()
# Out:
#                    id  Name         X          Y  LONGITUDE   LATITUDE  \
# 0  550226818624942080   NaN -0.262150  51.391407  -0.262150  51.391407
# 1  550226823314178048   NaN -0.149466  51.492560  -0.149466  51.492561
# 2  550226827944660992   NaN -0.014891  51.354042  -0.014891  51.354042
# 3  550226837537058816   NaN  0.006698  51.532020   0.006698  51.532021
# 4  550227214227505152   NaN  0.214417  51.582535   0.214417  51.582535
#
#            MESSAGEDATE     USERID   USERSCREENNAME  \
# 0  31/12/2014 09:47:50  113918054     12Elbestreet
# 1  31/12/2014 09:47:52  465989904  alice_foster_95
# 2  31/12/2014 09:47:53   55872342      MissGee_Pee
# 3  31/12/2014 09:47:55  147266450    vinita_ramtri
# 4  31/12/2014 09:49:25  518928608    CallumGordon7
#
#                                          MESSAGETEXT  \
# 0  @julieo25 Not yet got tics for Liverpool waiti...
# 1     So. Many. Accents #alicesadventureswithmegabus
# 2  If it doesn't make you happy by December 31st....
# ...

# %%
london_tweets["DATETIME"] = pd.to_datetime(london_tweets.MESSAGEDATE, format="%d/%m/%Y %H:%M:%S")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
london_tweets.head()
# Out:
#                    id  Name         X          Y  LONGITUDE   LATITUDE  \
# 0  550226818624942080   NaN -0.262150  51.391407  -0.262150  51.391407
# 1  550226823314178048   NaN -0.149466  51.492560  -0.149466  51.492561
# 2  550226827944660992   NaN -0.014891  51.354042  -0.014891  51.354042
# 3  550226837537058816   NaN  0.006698  51.532020   0.006698  51.532021
# 4  550227214227505152   NaN  0.214417  51.582535   0.214417  51.582535
#
#            MESSAGEDATE     USERID   USERSCREENNAME  \
# 0  31/12/2014 09:47:50  113918054     12Elbestreet
# 1  31/12/2014 09:47:52  465989904  alice_foster_95
# 2  31/12/2014 09:47:53   55872342      MissGee_Pee
# 3  31/12/2014 09:47:55  147266450    vinita_ramtri
# 4  31/12/2014 09:49:25  518928608    CallumGordon7
#
#                                          MESSAGETEXT  \
# 0  @julieo25 Not yet got tics for Liverpool waiti...
# 1     So. Many. Accents #alicesadventureswithmegabus
# 2  If it doesn't make you happy by December 31st....
# ...

# %%
for location in london_tweets.LOCATION.unique():
    print(location)
# Out:
# Kingston upon Thames; London
# London; England
# New Addington; London
# Stratford; London
# Romford; London
# Camberwell; London
# Hackney; London
# Croydon; London
# Wandsworth; London
# East Ham; London
# Paddington; London
# Bexley; London
# Kensington; London
# Islington; London
# Hillingdon; London
# Camden Town; London
# Barnet; London
# Hounslow; London
# City of London; London
# Ealing; London
# Lambeth; London
# Walthamstow; London
# Poplar; London
# Harrow; London
# Bromley; London
# Crayford; London
# Ilford; London
# Brent; London
# Eltham; London
# Richmond; London
# Enfield; London
# Greenwich; London
# Sutton; London
# Lewisham; London
# Hammersmith; London
# Barking; London
# Tottenham; London
# Merton; London
# Southall; London
# Harefield; London
# Downe; London
# Biggin Hill; London
# Hazlewood; London
# Keston; London
# Pratts Bottom; London
# Westerham; London

# %%
london_tweets.LOCATION.unique().size
# Out:
# 46

# %%
london_tweets.groupby("USERID").agg("count")
# Out:
# USERID
# 5260           1
# 12249          1
# 12294          4
# 12329          1
# 13536          2
# 13550          1
# 13697          1
# 15633          1
# 17633          2
# 19833          1
# 20693          3
# 31253          7
# 33943          1
# 48213          2
# 54893          3
# 55143         10
# 64623          4
# 72573          6
# 615743         1
# 620333        41
# 625893        12
# 638513         6
# 652193        13
# 681673         1
# 702613         1
# 751593         1
# 754966         1
# 755973         1
# 777993         3
# 786491        26
#               ..
# 2951844964     9
# 2951897345     1
# 2952096059     3
# 2952246365    63
# 2952253457     1
# 2952356919     1
# 2952368530     3
# 2952937811     4
# 2953209717     1
# 2953363731     4
# 2953593267     1
# 2953643266     1
# 2953927781     5
# 2953940476     3
# 2953985985     1
# 2954073310     1
# 2954744128     1
# 2954764245     2
# 2954774374     5
# 2954807577     2
# 2954947847     3
# ...

# %%
london_tweets[london_tweets.USERID == 465989904]
# Out:
#                       id  Name         X          Y  LONGITUDE   LATITUDE  \
# 1     550226823314178048   NaN -0.149466  51.492560  -0.149466  51.492561
# 9     550227982095482880   NaN -0.149511  51.492496  -0.149511  51.492496
# 2312  550227120765796352   NaN -0.149431  51.492657  -0.149431  51.492657
# 2541  550230745533657088   NaN -0.161403  51.486214  -0.161403  51.486214
# 3170  550211367249403904   NaN -0.047870  51.414207  -0.047870  51.414207
#
#               MESSAGEDATE     USERID   USERSCREENNAME  \
# 1     31/12/2014 09:47:52  465989904  alice_foster_95
# 9     31/12/2014 09:52:28  465989904  alice_foster_95
# 2312  31/12/2014 09:49:02  465989904  alice_foster_95
# 2541  31/12/2014 10:03:27  465989904  alice_foster_95
# 3170  31/12/2014 08:46:27  465989904  alice_foster_95
#
#                                             MESSAGETEXT            LOCATION  \
# 1        So. Many. Accents #alicesadventureswithmegabus     London; England
# ...

# %%
london_tweets[~london_tweets.HASHTAGS.isnull()]
# Out:
#                         id  Name         X          Y  LONGITUDE   LATITUDE  \
# 1       550226823314178048   NaN -0.149466  51.492560  -0.149466  51.492561
# 7       550227602011856896   NaN -0.104869  51.509530  -0.104869  51.509529
# 9       550227982095482880   NaN -0.149511  51.492496  -0.149511  51.492496
# 14      550228347239034880   NaN -0.163065  51.500072  -0.163065  51.500072
# 18      550228719391232000   NaN -0.208465  51.516144  -0.208465  51.516144
# 31      550229822233137153   NaN -0.159024  51.512875  -0.159024  51.512875
# 34      550230122817921025   NaN -0.262078  51.516514  -0.262078  51.516514
# 37      550230484979310593   NaN -0.134583  51.510036  -0.134583  51.510036
# 46      550231670881021952   NaN -0.359448  51.470387  -0.359448  51.470387
# 51      550232038377541632   NaN -0.187663  51.510986  -0.187663  51.510986
# 66      550232515748036609   NaN -0.032182  51.532207  -0.032182  51.532207
# ...

# %%
# Need to split on HASHTAGS as tweets have multiple hashtags

tweets_with_tags = london_tweets[~london_tweets.HASHTAGS.isnull()]

tweets_with_tags.groupby("HASHTAGS").agg("count")

# london_tweets.groupby("HASHTAGS").agg("count")

# g = df_agg["id"].groupby(level=0, group_keys=False)

# g.nlargest(3)
# Out:
#                                                     id  Name   X   Y  \
# HASHTAGS
#                                                      3     0   3   3
#                                                     10     0  10  10
#                                                     31     0  31  31
#                                                     15     0  15  15
#                                                      8     0   8   8
#                                                      3     0   3   3
#                                                      2     0   2   2
#                                                      3     0   3   3
#                                                      1     0   1   1
#                                                      2     0   2   2
#                                                      6     0   6   6
#                                                      3     0   3   3
# ...
