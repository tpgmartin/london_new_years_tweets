# %%
import datetime
import math
import matplotlib.pyplot as plt
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import *
import numpy as np
import pandas as pd
import re
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.metrics import pairwise_distances
import string

# %%
borough_to_cluster = pd.read_csv("./data/borough_to_cluster.csv")

# %%
borough_to_cluster.head()
# Out:
#                LOCATION  Cluster
# 0  Barking and Dagenham        1
# 1                Barnet        1
# 2                Bexley        1
# 3                 Brent        2
# 4               Bromley        1

# %%
borough_to_cluster.LOCATION
# Out:
# 0       Barking and Dagenham
# 1                     Barnet
# 2                     Bexley
# 3                      Brent
# 4                    Bromley
# 5                     Camden
# 6             City of London
# 7                    Croydon
# 8                     Ealing
# 9                    Enfield
# 10                 Greenwich
# 11                   Hackney
# 12    Hammersmith and Fulham
# 13                  Haringey
# 14                    Harrow
# 15                  Havering
# 16                Hillingdon
# 17                  Hounslow
# 18                 Islington
# 19    Kensington and Chelsea
# 20      Kingston upon Thames
# 21                   Lambeth
# 22                  Lewisham
# 23                    Merton
# 24                    Newham
# 25                 Redbridge
# 26      Richmond upon Thames
# 27                 Southwark
# 28                    Sutton
# 29             Tower Hamlets
# 30            Waltham Forest
# 31                Wandsworth
# 32               Westminster
# Name: LOCATION, dtype: object

# %%
demographics = pd.read_csv("./data/london_borough_demographics.csv")

# %%
demographics.head()
# Out:
#               area_name inner_outer_london  prop_aged_0_15  prop_working_age  \
# 0  Barking and Dagenham       Outer London            27.2              63.1
# 1                Barnet       Outer London            21.1              64.9
# 2                Bexley       Outer London            20.6              62.9
# 3                 Brent       Outer London            20.9              67.8
# 4               Bromley       Outer London            19.9              62.6
#
#    prop_aged_over_65  prop_residents_born_abroad  unemployment_rate  \
# 0                9.7                        37.8               11.0
# 1               14.0                        35.2                8.5
# 2               16.6                        16.1                7.6
# 3               11.3                        53.9                7.5
# 4               17.5                        18.3                5.3
#
#   gross_annual_pay  crime_rate_per_thousand  median_house_price  \
# 0            27886                     83.4              243500
# 1            33443                     62.7              445000
# 2            34350                     51.8              275000
# 3            29812                     78.8              407250
# 4            37682                     64.1              374975
#
#    home_owned_outright  home_being_bought_with_mortgage  \
# 0                 16.4                             27.4
# 1                 32.4                             25.2
# 2                 38.1                             35.3
# 3                 22.2                             22.6
# 4                 37.8                             34.9
#
#    turnout_local_elections
# 0                     36.5
# 1                     40.5
# 2                     39.6
# 3                     36.3
# 4                     40.8

# %%
data = demographics.merge(borough_to_cluster, left_on='area_name', right_on='LOCATION', how='inner')

# %%
data.head()
# Out:
#               area_name inner_outer_london  prop_aged_0_15  prop_working_age  \
# 0  Barking and Dagenham       Outer London            27.2              63.1
# 1                Barnet       Outer London            21.1              64.9
# 2                Bexley       Outer London            20.6              62.9
# 3                 Brent       Outer London            20.9              67.8
# 4               Bromley       Outer London            19.9              62.6
#
#    prop_aged_over_65  prop_residents_born_abroad  unemployment_rate  \
# 0                9.7                        37.8               11.0
# 1               14.0                        35.2                8.5
# 2               16.6                        16.1                7.6
# 3               11.3                        53.9                7.5
# 4               17.5                        18.3                5.3
#
#   gross_annual_pay  crime_rate_per_thousand  median_house_price  \
# 0            27886                     83.4              243500
# 1            33443                     62.7              445000
# 2            34350                     51.8              275000
# 3            29812                     78.8              407250
# 4            37682                     64.1              374975
#
#    home_owned_outright  home_being_bought_with_mortgage  \
# 0                 16.4                             27.4
# 1                 32.4                             25.2
# 2                 38.1                             35.3
# 3                 22.2                             22.6
# 4                 37.8                             34.9
#
#    turnout_local_elections              LOCATION  Cluster
# 0                     36.5  Barking and Dagenham        1
# 1                     40.5                Barnet        1
# 2                     39.6                Bexley        1
# 3                     36.3                 Brent        2
# 4                     40.8               Bromley        1

# %%
from sklearn.svm import LinearSVC

# %%
# 0 Redbridge
# 1 Newham
# 2 Southwark
# 3 Westminster
train = data.drop([23,24,26,31])
test = data.iloc[[23,24,26,31],:]

# %%
clf = LinearSVC(random_state=0, tol=1e-5, C=0.001)

# %%
X_train, y_train = train.drop(['Cluster'], axis=1), train[["Cluster"]]

# %%
X_test, y_test = test.drop(['Cluster'], axis=1), test[["Cluster"]]

# %%
X_train.head()
# Out:
#               area_name inner_outer_london  prop_aged_0_15  prop_working_age  \
# 0  Barking and Dagenham       Outer London            27.2              63.1
# 1                Barnet       Outer London            21.1              64.9
# 2                Bexley       Outer London            20.6              62.9
# 3                 Brent       Outer London            20.9              67.8
# 4               Bromley       Outer London            19.9              62.6
#
#    prop_aged_over_65  prop_residents_born_abroad  unemployment_rate  \
# 0                9.7                        37.8               11.0
# 1               14.0                        35.2                8.5
# 2               16.6                        16.1                7.6
# 3               11.3                        53.9                7.5
# 4               17.5                        18.3                5.3
#
#   gross_annual_pay  crime_rate_per_thousand  median_house_price  \
# 0            27886                     83.4              243500
# 1            33443                     62.7              445000
# 2            34350                     51.8              275000
# 3            29812                     78.8              407250
# 4            37682                     64.1              374975
#
#    home_owned_outright  home_being_bought_with_mortgage  \
# 0                 16.4                             27.4
# 1                 32.4                             25.2
# 2                 38.1                             35.3
# 3                 22.2                             22.6
# 4                 37.8                             34.9
#
#    turnout_local_elections              LOCATION
# 0                     36.5  Barking and Dagenham
# 1                     40.5                Barnet
# 2                     39.6                Bexley
# 3                     36.3                 Brent
# 4                     40.8               Bromley

# %%
y_train.head()
# Out:
#    Cluster
# 0        1
# 1        1
# 2        1
# 3        2
# 4        1

# %%
# columns = ["prop_aged_0_15", "prop_working_age", "prop_aged_over_65", "prop_residents_born_abroad", "unemployment_rate", "crime_rate_per_thousand", "median_house_price", "home_owned_outright", "home_being_bought_with_mortgage", "turnout_local_elections"]
# columns = ["prop_aged_over_65"]
# columns = ["home_owned_outright"]
# columns = ["home_being_bought_with_mortgage"]
columns = ["prop_aged_over_65", "home_owned_outright", "home_being_bought_with_mortgage"]

clf.fit(X_train[columns],y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=1e-05, verbose=0)

# %%
clf.predict(X_test[columns])
# Out:
# array([1, 1, 2, 1])

# %%
y_test
# Out:
#     Cluster
# 23        1
# 24        0
# 26        2
# 31        3
